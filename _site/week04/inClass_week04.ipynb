# %% [markdown]
# # In Class Notebook, Week 04

# %% [markdown]
# You can click on the GitHub URL of this notebook to access the file in near-real time: https://github.com/UIUC-iSchool-DataViz/is445_oauoag_fall2022/blob/master/week04/inClass_week04.ipynb
#
# Or you can copy-paste into the nbviewer interface for a plain-text rendering:
#
# https://kokes.github.io/nbviewer.js/viewer.html

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd

import ipywidgets

# %%
michigan_file = '/Users/jnaiman/Downloads/michigan_lld.flt'
michigan = np.fromfile(michigan_file, dtype='f4').reshape((5365,4201))
# shape and data type come from the documentation of this file
# https://www.ngdc.noaa.gov/mgg/greatlakes/michigan.html

# %%
michigan[michigan==-9999] = np.nan

# %%
# 1. hardcode some options we want to make interactive
colormap_name = 'Blues'
take_log = True

if take_log:
    # compressing data into few colors
    norm = matplotlib.colors.SymLogNorm(10)
else:
    # linear normalization
    norm = matplotlib.colors.Normalize()

plt.imshow(michigan,cmap=colormap_name, norm=norm)
plt.colorbar()
plt.clim(-352,352)
plt.show()
# Out:
# /Users/jnaiman/opt/anaconda3/envs/DataViz/lib/python3.7/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: default base may change from np.e to 10.  To suppress this warning specify the base keyword argument.

# %%
1, 5, 50
# Out:
# (1, 5, 50)

# %%
np.log10([1,5,50])
# Out:
# array([0.     , 0.69897, 1.69897])

# %%
-1,-5,-50
# Out:
# (-1, -5, -50)

# %%
-np.log10(np.abs([-1,-5,-50]))
# Out:
# array([-0.     , -0.69897, -1.69897])

# %%
# 2. turn hard-coded options into a function
#colormap_name = 'Blues'
#take_log = True

def make_michigan_plot(colormap_name,take_log=True):
    # on a mac --> select lines --> COMMAND ]
    # windows: select lines --> CMD ]
    if take_log:
        # compressing data into few colors
        norm = matplotlib.colors.SymLogNorm(10)
    else:
        # linear normalization
        norm = matplotlib.colors.Normalize()

    plt.imshow(michigan,cmap=colormap_name, norm=norm)
    plt.colorbar()
    plt.clim(-352,352)
    plt.show()

# %%
# 2.5 -- test your function!
make_michigan_plot('seismic')
# Out:
# /Users/jnaiman/opt/anaconda3/envs/DataViz/lib/python3.7/site-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: default base may change from np.e to 10.  To suppress this warning specify the base keyword argument.
#   # Remove the CWD from sys.path while we load stuff.

# %%
make_michigan_plot('seismic',take_log=False)

# %%
# 3. decorate our function with a ipywidgets.interact
# with options in the function as parameters in @ipywidgets.interact decorator
@ipywidgets.interact(colormap_name=plt.colormaps(), take_log=True)
def make_michigan_plot(colormap_name,take_log=True):
    # on a mac --> select lines --> COMMAND ]
    # windows: select lines --> CMD ]
    if take_log:
        # compressing data into few colors
        norm = matplotlib.colors.SymLogNorm(10)
    else:
        # linear normalization
        norm = matplotlib.colors.Normalize()

    plt.imshow(michigan,cmap=colormap_name, norm=norm)
    plt.colorbar()
    plt.clim(-352,352)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='colormap_name', options=('Accent', 'Accent_r', 'Blues', 'Blues_r',…

# %%
plt.colormaps()
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'CMRmap',
#  'CMRmap_r',
#  'Dark2',
#  'Dark2_r',
#  'GnBu',
#  'GnBu_r',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'PRGn',
#  'PRGn_r',
#  'Paired',
#  'Paired_r',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'PiYG',
#  'PiYG_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuOr',
#  'PuOr_r',
#  'PuRd',
#  'PuRd_r',
#  'Purples',
#  'Purples_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdPu',
#  'RdPu_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Reds',
#  'Reds_r',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'Spectral',
#  'Spectral_r',
#  'Wistia',
#  'Wistia_r',
#  'YlGn',
#  'YlGnBu',
#  'YlGnBu_r',
#  'YlGn_r',
#  'YlOrBr',
#  'YlOrBr_r',
#  'YlOrRd',
#  'YlOrRd_r',
#  'afmhot',
#  'afmhot_r',
#  'autumn',
#  'autumn_r',
#  'binary',
#  'binary_r',
#  'bone',
#  'bone_r',
#  'brg',
#  'brg_r',
#  'bwr',
#  'bwr_r',
#  'cividis',
#  'cividis_r',
#  'cool',
#  'cool_r',
#  'coolwarm',
#  'coolwarm_r',
#  'copper',
#  'copper_r',
#  'cubehelix',
#  'cubehelix_r',
#  'flag',
#  'flag_r',
#  'gist_earth',
#  'gist_earth_r',
#  'gist_gray',
#  'gist_gray_r',
#  'gist_heat',
#  'gist_heat_r',
#  'gist_ncar',
#  'gist_ncar_r',
#  'gist_rainbow',
#  'gist_rainbow_r',
#  'gist_stern',
#  'gist_stern_r',
#  'gist_yarg',
#  'gist_yarg_r',
#  'gnuplot',
#  'gnuplot2',
#  'gnuplot2_r',
#  'gnuplot_r',
#  'gray',
#  'gray_r',
#  'hot',
#  'hot_r',
#  'hsv',
#  'hsv_r',
#  'inferno',
#  'inferno_r',
#  'jet',
#  'jet_r',
#  'magma',
#  'magma_r',
#  'nipy_spectral',
#  'nipy_spectral_r',
#  'ocean',
#  'ocean_r',
#  'pink',
#  'pink_r',
#  'plasma',
#  'plasma_r',
#  'prism',
#  'prism_r',
#  'rainbow',
#  'rainbow_r',
#  'seismic',
#  'seismic_r',
#  'spring',
#  'spring_r',
#  'summer',
#  'summer_r',
#  'tab10',
#  'tab10_r',
#  'tab20',
#  'tab20_r',
#  'tab20b',
#  'tab20b_r',
#  'tab20c',
#  'tab20c_r',
#  'terrain',
#  'terrain_r',
#  'twilight',
#  'twilight_r',
#  'twilight_shifted',
#  'twilight_shifted_r',
#  'viridis',
#  'viridis_r',
#  'winter',
#  'winter_r']

# %% [markdown]
# ## More kinds of widgets

# %%
itext = ipywidgets.IntText()
itext
# Out:
# IntText(value=0)

# %%
itext.value
# Out:
# 5

# %%
itext.value = 5

# %%
ip = ipywidgets.IntProgress(value=50)
ip
# Out:
# IntProgress(value=50)

# %%
irange = ipywidgets.IntSlider(min=0,max=100,step=1)
irange
# Out:
# IntSlider(value=0)

# %%
ip.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'bar_style',
#  'description',
#  'description_tooltip',
#  'layout',
#  'max',
#  'min',
#  'orientation',
#  'style',
#  'value']

# %%
irange.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'continuous_update',
#  'description',
#  'description_tooltip',
#  'disabled',
#  'layout',
#  'max',
#  'min',
#  'orientation',
#  'readout',
#  'readout_format',
#  'step',
#  'style',
#  'value']

# %%
ipywidgets.jslink?

# %%
ipywidgets.jslink((ip,'value'),(irange,'value'))
# Out:
# Link(source=(IntProgress(value=50), 'value'), target=(IntSlider(value=0), 'value'))

# %%
ip
# Out:
# IntProgress(value=50)

# %%
irange
# Out:
# IntSlider(value=50)

# %%
ipywidgets.VBox([ip,irange])
# Out:
# VBox(children=(IntProgress(value=38), IntSlider(value=38)))

# %%
ip2 = ipywidgets.IntProgress(value=70)
irange2 = ipywidgets.IntSlider(min=0,max=100,step=1)
ipywidgets.link((ip2,'value'),(irange2,'value'))
ipywidgets.VBox([ip2,irange2])
# Out:
# VBox(children=(IntProgress(value=70), IntSlider(value=70)))

# %%
ipywidgets.link?

# %%
button = ipywidgets.Button(description='I am a button.')
button
# Out:
# Button(description='I am a button.', style=ButtonStyle())
# I have been clicked!
# I have been clicked!
# I have been clicked!

# %%
def say_click(event): # event?
    print('I have been clicked!')

# %%
button.on_click(say_click) # what happens when I click to the "say_click" function

# %%
ip = ipywidgets.IntProgress()

# %%
button_plus = ipywidgets.Button(description='+10')
button_minus = ipywidgets.Button(description='-10')

# %%
ipywidgets.HBox([button_minus, ip, button_plus])
# Out:
# HBox(children=(Button(description='-10', style=ButtonStyle()), IntProgress(value=0), Button(description='+10',…
# Button(description='+10', style=ButtonStyle())
# Button(description='+10', style=ButtonStyle())

# %%
ip.value
# Out:
# 0

# %%
ip.value = 50

# %%
def button_click_plus(event): # event?
    #print(event)
    ip.value += 10 # ip.value = ip.value + 10

# %%
button_plus.on_click(button_click_plus)

# %%
def button_click_minus(event): # event?
    ip.value -= 10
button_minus.on_click(button_click_minus)

# %%
islider = ipywidgets.IntSlider(min=0,max=10,step=1, orientation='vertical')
islider
# Out:
# IntSlider(value=0, max=10, orientation='vertical')

# %%
islider.value
# Out:
# 4

# %%
islider.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'continuous_update',
#  'description',
#  'description_tooltip',
#  'disabled',
#  'layout',
#  'max',
#  'min',
#  'orientation',
#  'readout',
#  'readout_format',
#  'step',
#  'style',
#  'value']

# %%
islider.style.keys
# Out:
# ['_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'description_width',
#  'handle_color']

# %%
islider.style.handle_color='#FFFF66'

# %%
islider
# Out:
# IntSlider(value=6, max=10, orientation='vertical', style=SliderStyle(handle_color='#750075'))

# %%
cp = ipywidgets.ColorPicker()
cp
# Out:
# ColorPicker(value='black')

# %%
ipywidgets.link((cp,'value'),(islider.style, 'handle_color'))

# %% [markdown]
# ## Traitlets

# %%
class MyObject():
    name = 'unnamed'
    age = -1

# %%
myobj = MyObject()

# %%
myobj.name, myobj.age
# Out:
# ('unnamed', -1)

# %%
myobj.name = 'Bob'
myobj.age = 47

# %%
myobj.name, myobj.age
# Out:
# ('Bob', 47)

# %%
print('Hello my name is:', myobj.name, 'and I am', myobj.age, 'years old')
# Out:
# Hello my name is: Bob and I am 47 years old

# %%
myobj.name = 'Linda'
myobj.age = 45

# %%
print('Hello my name is:', myobj.name, 'and I am', myobj.age, 'years old')
# Out:
# Hello my name is: Linda and I am 45 years old

# %%
import traitlets

# %%
class MyTraitletsObject(traitlets.HasTraits):
    name = traitlets.Unicode("unnamed") # fancy way of saying "string"
    age = traitlets.Int(-1) # fancy way of saying Int

# %%
mytobj = MyTraitletsObject()
mytobj.age = 47
mytobj.name = 'Bob'

# %%
print('Hello my name is:', mytobj.name, 'and I am', mytobj.age, 'years old')
# Out:
# Hello my name is: Bob and I am 47 years old

# %%
def name_changed(change): # sort of like the mysterious "event", but there are more details
    print(change)
    
mytobj.observe(name_changed, ['name']) # looking for changes in "name" trait of mytobj

# %%
mytobj.name = 'Linda'
# Out:
# {'name': 'name', 'old': 'Bob', 'new': 'Linda', 'owner': <__main__.MyTraitletsObject object at 0x7fd5a1217b50>, 'type': 'change'}

# %%
def name_changed2(change):
    print('Hello, my name is:', change['new'], 'and I am', change['owner'].age, 'years old')
    
mytobj.observe(name_changed2,['name'])

# %%
mytobj.name = 'Bob'
# Out:
# {'name': 'name', 'old': 'Linda', 'new': 'Bob', 'owner': <__main__.MyTraitletsObject object at 0x7fd5a1217b50>, 'type': 'change'}
# Hello, my name is: Bob and I am 47 years old

# %%
mytobj.unobserve(name_changed, ['name'])

# %%
mytobj.name = "Linda"
# Out:
# Hello, my name is: Linda and I am 47 years old

# %%
def age_changed(change):
    print('Hello, my name is', change['owner'].name, 'and I am NOW', change['new'], 'years old')
    
mytobj.observe(age_changed, ['age'])

# %%
mytobj.age = 45
# Out:
# Hello, my name is Linda and I am NOW 45 years old

# %%
mytobj.name = "Louise"
mytobj.age = 8
# Out:
# Hello, my name is: Louise and I am 45 years old
# Hello, my name is Louise and I am NOW 8 years old

# %% [markdown]
# ### Some notes for the homework

# %%
bf = pd.read_csv('https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_bcubcg_fall2022/main/data/bfro_reports_fall2022.csv', 
                parse_dates = ["date"]
)

# %%
bf.head()
# Out:
#                                             observed  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1  heh i kinda feel a little dumb that im reporti...
# 2  I was on my way to Claremont from Lebanon on R...
# 3  I was northeast of Macy Nebraska along the Mis...
# 4  While this incident occurred a long time ago, ...
#
#                                     location_details  \
# 0                  East side of Prince William Sound
# 1  the road is off us rt 80, i dont know the exit...
# 2  Close to Claremont down 120 not far from Kings...
# 3      Latitude & Longitude :  42.158230  -96.344197
# 4  Ward County, Just outside of a the Minuteman T...
#
#                            county          state  season  \
# 0  Valdez-Chitina-Whittier County         Alaska    Fall
# 1                   Warren County     New Jersey    Fall
# 2                 Sullivan County  New Hampshire  Summer
# 3                 Thurston County       Nebraska  Spring
# 4                     Ward County   North Dakota  Spring
#
#                                                title  latitude  longitude  \
# 0                                                NaN       NaN        NaN
# 1                                                NaN       NaN        NaN
# 2  Report 55269: Dawn sighting at Stevens Brook o...  43.41549  -72.33093
# 3  Report 59757: Possible daylight sighting of a ...  42.15685  -96.34203
# 4  Report 751: Hunter describes described being s...  48.25422 -101.31660
#
#         date   number  ... precip_intensity precip_probability  precip_type  \
# 0        NaT   1261.0  ...              NaN                NaN          NaN
# 1        NaT    438.0  ...              NaN                NaN          NaN
# 2 2016-06-07  55269.0  ...            0.001                0.7         rain
# 3 2018-05-25  59757.0  ...            0.000                0.0          NaN
# 4 2000-04-21    751.0  ...              NaN                NaN         rain
#
#    pressure                            summary  uv_index  visibility  \
# 0       NaN                                NaN       NaN         NaN
# 1       NaN                                NaN       NaN         NaN
# 2    998.87  Mostly cloudy throughout the day.       6.0        9.70
# 3   1008.07      Partly cloudy in the morning.      10.0        8.25
# 4   1011.47       Partly cloudy until evening.       6.0       10.00
#
#    wind_bearing  wind_speed                                      location
# 0           NaN         NaN                                           NaN
# 1           NaN         NaN                                           NaN
# 2         262.0        0.49  POINT(-72.33093000000001 43.415490000000005)
# 3         193.0        3.33            POINT(-96.34203000000001 42.15685)
# 4         237.0       11.14           POINT(-101.3166 48.254220000000004)
#
# [5 rows x 29 columns]

# %%
plt.plot(bf['longitude'], bf['latitude'],'.')
plt.show()

# %%
bf.columns
# Out:
# Index(['observed', 'location_details', 'county', 'state', 'season', 'title',
#        'latitude', 'longitude', 'date', 'number', 'classification', 'geohash',
#        'temperature_high', 'temperature_mid', 'temperature_low', 'dew_point',
#        'humidity', 'cloud_cover', 'moon_phase', 'precip_intensity',
#        'precip_probability', 'precip_type', 'pressure', 'summary', 'uv_index',
#        'visibility', 'wind_bearing', 'wind_speed', 'location'],
#       dtype='object')

# %%
plt.scatter(bf['longitude'],bf['latitude'],c=bf['wind_speed'],cmap='rainbow')
plt.show()

# %%
bf.hist(column='longitude')
plt.show()

# %% [markdown]
# ## More fun things with widgets!

# %%
tx1 = ipywidgets.Textarea("Hi I am a text box (1)")

# %%
tx1
# Out:
# Textarea(value='Hi I am a text box (1)')

# %%
tx2 = ipywidgets.Textarea("Hi I am a text box (2)")
tx3 = ipywidgets.Textarea("Hi I am a text box (3)")
tx4 = ipywidgets.Textarea("Hi I am a text box (4)")

# %%
ipywidgets.VBox([tx1,tx2,tx3,tx4])
# Out:
# VBox(children=(Textarea(value='Hi I am a text box (1)'), Textarea(value='Hi I am a text box (2)'), Textarea(va…

# %%
ipywidgets.VBox([ipywidgets.HBox([tx1,tx2]),ipywidgets.HBox([tx3,tx4])])
# Out:
# VBox(children=(HBox(children=(Textarea(value='Hi I am a text box (1)'), Textarea(value='Hi I am a text box (2)…

# %%
bigBox1 = ipywidgets.HBox([tx1,tx2])
bigBox2 = ipywidgets.HBox([tx3,tx4])

ipywidgets.VBox([bigBox1,bigBox2])
# Out:
# VBox(children=(HBox(children=(Textarea(value='Hi I am a text box (1)'), Textarea(value='Hi I am a text box (2)…

# %%
ipywidgets.Tab([tx1,tx2,tx3,tx4])
# Out:
# Tab(children=(Textarea(value='Hi I am a text box (1)'), Textarea(value='Hi I am a text box (2)'), Textarea(val…

# %%
ipywidgets.Accordion([tx1,tx2,tx3,tx])
